# %% [markdown]
# # Epoching

# %%
# %matplotlib notebook

# %%
import pdb
import matplotlib.pyplot as plt
import numpy as np

from utils.analyzer import Analyzer
from utils.data_loader import DataLoader
from utils.preprocessing import Preprocessing

# %% [markdown]
# # Load preprocessed data

# %%
generate_report = False
Ref = "origin"
exp_counter = 1

# %%
analyzer = Analyzer(exp_counter=exp_counter, low_freq=0.05, hi_freq=5,
                    pick_channels=['C3', 'C1', 'Cz', 'C2', 'C4'], generate_report=generate_report)
analyzer.load_preprocessed_data(special_name='referenced_using_{}'.format(Ref), duration=100)
# Out:
# Embedding : jquery.js
# Embedding : jquery-ui.min.js
# Embedding : bootstrap.min.js
# Embedding : jquery-ui.min.css
# Embedding : bootstrap.min.css
# Opening raw data file ..\processed_data\consecutive_data\sub1_processed_BPF_0.05Hz_5Hz_referenced_using_origin.fif...
# D:\OneDrive - University of Waterloo\Jiansheng\MRCP_folder\MRCP_online_interface\Processing_package_for_Stevie\offline_processing_slim\analyzer.py:45: RuntimeWarning: This filename (..\processed_data\consecutive_data\sub1_processed_BPF_0.05Hz_5Hz_referenced_using_origin.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz or _meg.fif
#   self.preprocessed_data = mne.io.read_raw_fif(file_path, preload=True)
#     Range : 0 ... 2611303 =      0.000 ...  5222.606 secs
# Ready.
# Reading 0 ... 2611303  =      0.000 ...  5222.606 secs...
# <img src="data:image/png;base64,..." width="960.0000254313157">

# %% [markdown]
# # Choose task to epoch

# %% [markdown]
# **Change 'task_to_epoch' from 0 to 3 to epoch each task sequentially.**

# %%
task =['EMG_WE_l', 'EMG_WE_r', 'EMG_IE_l', 'EMG_IE_r']
task_to_epoch = 1

# %% [markdown]
# ## Bad epoch removal

# %% [markdown]
# **Both image plots of interested channels and epochs plot are shown up below. Best practice is to check both plots to find out
# artifact epochs and mark them red in the epochs plot to remove them.**

# %%
# create epochs for each task
epochs = analyzer.epoch_data(tmin=-3, tmax=5, baseline=None, cue_type=task[task_to_epoch], \
                             caption='{} signal'.format(task[task_to_epoch]))
# Out:
# Used Annotations descriptions: ['EMG_IE_l', 'EMG_IE_r', 'EMG_WE_l', 'EMG_WE_r', 'IE_l', 'IE_r', 'Idle', 'WE_l', 'WE_r', 'focus', 'one', 'prepare', 'two']
# Not setting metadata
# Not setting metadata
# 1259 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1259 events and 4001 original time points ...
# 0 bad epochs dropped
# <img src="data:image/png;base64,..." width="638.888905813665">
# Not setting metadata
# Not setting metadata
# 45 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# <img src="data:image/png;base64,..." width="638.888905813665">
# Not setting metadata
# Not setting metadata
# 45 matching events found
# No baseline correction applied
# 0 projection items activated
# 0 bad epochs dropped
# <img src="data:image/png;base64,..." width="638.888905813665">
# Not setting metadata
# Not setting metadata
# 45 matching events found
# ...

# %% [markdown]
# ## Check epochs after removing bad epochs

# %%
epochs # one artifact has been removed, there was 44 epochs before removal
# Out:
# <Epochs |  43 events (all good), -3 - 5 sec, baseline off, ~40.8 MB, data loaded,
#  'EMG_WE_r': 43>

# %% [markdown]
# ## Save to 'processed_data \  epoched_data'

# %%
analyzer.save_epoched_data(epoch=epochs, caption='{}_signal'.format(task[task_to_epoch]))
# Out:
# D:\OneDrive - University of Waterloo\Jiansheng\MRCP_folder\MRCP_online_interface\Processing_package_for_Stevie\offline_processing_slim\analyzer.py:190: RuntimeWarning: This filename (..\processed_data\epoched_data\sub1_signal_epochs_-3s_5s_0.05Hz_5Hz_EMG_IE_r_signal.fif) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   self.hi_freq, caption), overwrite=True)
